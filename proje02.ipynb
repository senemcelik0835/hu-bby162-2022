# %% [markdown]
# <a href="https://colab.research.google.com/github/senemcelik0835/hu-bby162-2022/blob/main/proje02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
adiniz = input("lütfen adınızı giriniz :")
print("merhaba " + adiniz + " seninle bir oyun oynayacağız")
print("1)basit - 2)orta - 3)ileri - 4)Çıkış")
seviye = input("lütfen oynamak istediğiniz seviyeyi seçiniz: ileri/orta/basit/çıkış")
seviye.lower ()

if seviye == "basit":
  print('sahip olduğunuz can sayısı:10')
  KelimeListesiBasit = ['random', 'bulut', 'vakum','artvin']
  import random
  from secilenKelime import KelimeListesiBasit

  def get_adamasmacaB ():
    secilenKelime = random.choice(KelimeListesiBasit)
    return secilenKelime.lower()

  def play(secilenKelime):
    secilenKelime_display = "_" +len(secilenKelime) #kelime uzunluğu kadar alt tire yazdırmak için.
    tahminEdilen = False
    tahminEdilen_harfler = [] #tahminde söylenen harfler için dizin
    tahminEdlen_kelimeler = [] # tahminde söylenen kelimeler için dizin
    can:10
    
    print('Hadi başlayalım. %d hakkın var.' %(can))
    print(secilenKelime_display)
    print ("\n") # Kelimelerin karışmaması için alt alta yazdırır.

    while not tahminEdilen and can > 0: #tahminedilen false değil ve can 0'dan büyükse döngü devam etsin diye.
      tahmin = input('Tahminde bulunun: ').lower()
        if tahmin in tahminEdilen_harfler:
          print('%s harfini daha önce denediniz.' %(tahmin))
        elif tahmin not in secilenKelime:
          can -=1
          print('%s harfi kelimede yok. %d hakkın kaldı'%(tahmin,can))
          tahminEdilen_harfler.append(tahmin) # Dizinin içine tahmin eklendi.
        else:
          print('%s harfi kelimede var.'%(tahmin))
          tahminEdilen_harfler.append(tahmin) # Dizinin içine tahmin eklendi.
          if "_" not in secilenKelime_display:
            tahminEdilen = True
      if tahmin== secilenKelime:
        tahminEdilen = True
        secilenKelime_display =secilenKelime
      elif tahmin in tahminEdlen_kelimeler:
        print('%s bu kelimeyi daha önce denediniz' %(tahmin))
      else:
        print('Doğru cvp değil :(')
        tahminEdilen_harfler.append(tahmin)
        can -=1
    
    else:
      print('Geçersiz Tahmin..')
    print(secilenKelime_display)
    print('\n')

  if tahminEdilen = True:
      print('Tebrikler..')
  else:
      print('Malesef Kazanamadınız :(' )


if seviye == "orta":
  print('sahip olduğunuz can sayısı:5')
  KelimeListesiOrta = ['gökyüzü', 'güvenlik', 'hoşgörü','karınca']
  import random
  from secilenKelime import KelimeListesiOrta

  def get_adamasmacaO ():
    secilenKelime = random.choice(KelimeListesiOrta)
    return secilenKelime.lower()

  def play(secilenKelime):
    secilenKelime_display = "_" +len(secilenKelime) #kelime uzunluğu kadar alt tire yazdırmak için.
    tahminEdilen = False
    tahminEdilen_harfler = [] #tahminde söylenen harfler için dizin
    tahminEdlen_kelimeler = [] # tahminde söylenen kelimeler için dizin
    can:5

    print('Hadi başlayalım. %d hakkın var.' %(can))
    print(secilenKelime_display)
    print ("\n") # Kelimelerin karışmaması için alt alta yazdırır.

    while not tahminEdilen and can > 0: #tahminedilen false değil ve can 0'dan büyükse döngü devam etsin diye.
      tahmin = input('Tahminde bulunun: ').lower()
        if tahmin in tahminEdilen_harfler:
          print ('%s harfini daha önce denediniz.' %(tahmin))
        elif tahmin not in secilenKelime:
          can -=1
          print('%s harfi kelimede yok. %d hakkın kaldı'%(tahmin,can))
          tahminEdilen_harfler.append(tahmin) # Dizinin içine tahmin eklendi.
        else:
          print('%s harfi kelimede var.'%(tahmin))
          tahminEdilen_harfler.append(tahmin) # Dizinin içine tahmin eklendi.
          if "_" not in secilenKelime_display:
            tahminEdilen = True
      if tahmin== secilenKelime:
        tahminEdilen = True
        secilenKelime_display =secilenKelime
      elif tahmin in tahminEdlen_kelimeler:
        print('%s bu kelimeyi daha önce denediniz' %(tahmin))
      else:
        print('Doğru cvp değil :(')
        tahminEdilen_harfler.append(tahmin)
        can -=1
    
    else:
      print('Geçersiz Tahmin..')
    print(secilenKelime_display)
    print('\n')

  if tahminEdilen = True:
      print('Tebrikler..')
  else:
      print('Malesef Kazanamadınız :(' )


if seviye == "ileri":
  print('sahip olduğunuz can sayısı:3')
  KelimeListesiİleri = ['müzikçalar', 'edebiyatçı', 'fabrikatör','çayırçimen']
  import random
  from secilenKelime import KelimeListesiİleri

  def get_adamasmacaİ ():
    secilenKelime = random.choice(KelimeListesiİleri)
    return secilenKelime.lower()

  def play(secilenKelime):
    secilenKelime_display = "_" +len(secilenKelime) #kelime uzunluğu kadar alt tire yazdırmak için.
    tahminEdilen = False
    tahminEdilen_harfler = [] #tahminde söylenen harfler için dizin
    tahminEdlen_kelimeler = [] # tahminde söylenen kelimeler için dizin
    can:3

    print('Hadi başlayalım. %d hakkın var.' %(can))
    print(secilenKelime_display)
    print ("\n") # Kelimelerin karışmaması için alt alta yazdırır.

    while not tahminEdilen and can > 0: #tahminedilen false değil ve can 0'dan büyükse döngü devam etsin diye.
      tahmin = input('Tahminde bulunun: ').lower()
        if tahmin in tahminEdilen_harfler:
          print ('%s harfini daha önce denediniz.' %(tahmin))
        elif tahmin not in secilenKelime:
          can -=1
          print('%s harfi kelimede yok. %d hakkın kaldı'%(tahmin,can))
          tahminEdilen_harfler.append(tahmin) # Dizinin içine tahmin eklendi.
        else:
          print('%s harfi kelimede var.'%(tahmin))
          tahminEdilen_harfler.append(tahmin) # Dizinin içine tahmin eklendi.
          if "_" not in secilenKelime_display:
            tahminEdilen = True
      if tahmin== secilenKelime:
        tahminEdilen = True
        secilenKelime_display =secilenKelime
      elif tahmin in tahminEdlen_kelimeler:
        print('%s bu kelimeyi daha önce denediniz' %(tahmin))
      else:
        print('Doğru cvp değil :(')
        tahminEdilen_harfler.append(tahmin)
        can -=1
    
    else:
      print('Geçersiz Tahmin..')
    print(secilenKelime_display)
    print('\n')

  if tahminEdilen = True:
      print('Tebrikler..')
  else:
      print('Malesef Kazanamadınız :(' )
# Out:
#   File "<ipython-input-51-8713da6c29ba>", line 31
#     if tahmin in tahminEdilen_harfler:
#     ^
# IndentationError: unexpected indent
